# %%
import os
import time
import requests
import xml.etree.ElementTree as ET
import pandas as pd

# %%
# CONFIGURATION
CSV_PATH = "../church-fathers.csv"
OUTPUT_BASE = "../data/"
BASE_API = "https://mlat.uzh.ch/php_modules/navigate.php?load="
BASE_HOST = "https://mlat.uzh.ch"
BASE_DATA = "https://mlat.uzh.ch/data"
NS = {"cc": "http://mlat.uzh.ch/2.0"}

# HTTP SESSION
session = requests.Session()
session.headers.update({"User-Agent": "tei-downloader/1.1 (+https://example.org)"})


def fetch_xml_root(url: str, max_retries=3, backoff=1.0):
    for attempt in range(1, max_retries + 1):
        try:
            print(f"Fetching: {url}")
            r = session.get(url, timeout=20)
            r.raise_for_status()
            return ET.fromstring(r.content)
        except Exception as e:
            print(f"Warning: fetch failed ({e}), attempt {attempt}/{max_retries}")
            if attempt == max_retries:
                raise
            time.sleep(backoff * attempt)
    raise RuntimeError("unreachable")

# Convert server-side xml path to public URL
def normalize_xml_path_to_url(xml_path_text: str) -> str:
    if not xml_path_text:
        return None
    s = xml_path_text.strip()

    idx = s.find("/data/")
    if idx != -1:
        data_sub = s[idx:]
        return BASE_HOST + data_sub

    if s.startswith("/var/www/html"):
        idx2 = s.find("/data/")
        if idx2 != -1:
            return BASE_HOST + s[idx2:]
        remainder = s.replace("/var/www/html", "", 1)
        return BASE_HOST + remainder if remainder.startswith("/") else BASE_HOST + "/" + remainder

    if s.startswith("/data"):
        return BASE_HOST + s
    if s.startswith("data/"):
        return BASE_DATA + s[len("data"):]
    return BASE_DATA + "/" + s.lstrip("/")


def get_works_for_author(author_id: str):
    url = f"{BASE_API}{author_id}&group_by="
    root = fetch_xml_root(url)
    works = []
    for w in root.findall(".//cc:work", NS):
        wid = w.findtext("cc:idno", default="", namespaces=NS)
        name = w.findtext("cc:name", default="", namespaces=NS)
        if wid:
            works.append({"id": wid.strip(), "name": name.strip() if name else ""})
    return works


def get_texts_for_work(author_id: str, work_id: str):
    url = f"{BASE_API}{author_id}/{work_id}&group_by="
    root = fetch_xml_root(url)
    texts = []
    for txt in root.findall(".//cc:contents/cc:text", NS):
        tid = txt.findtext("cc:idno", default="", namespaces=NS)
        name = txt.findtext("cc:name", default="", namespaces=NS)
        if tid:
            texts.append({"id": tid.strip(), "name": name.strip() if name else ""})
    return texts


def download_text_xml(author_dir: str, author_id: str, work_id: str, text_id: str):
    if text_id:
        url = f"{BASE_API}{author_id}/{work_id}/{text_id}&group_by="
    else:
        url = f"{BASE_API}{author_id}/{work_id}&group_by="
    root = fetch_xml_root(url)

    xml_path_elem = root.find(".//cc:xml_file_path", NS)
    downloadable_elem = root.find(".//cc:xml_file_downloadable", NS)
    downloadable = True
    if downloadable_elem is not None and downloadable_elem.text:
        downloadable = downloadable_elem.text.strip().lower() == "true"

    if xml_path_elem is None or not xml_path_elem.text or not downloadable:
        print(f"No downloadable TEI at {author_id}/{work_id}/{text_id}")
        return False

    xml_path_text = xml_path_elem.text.strip()
    file_url = normalize_xml_path_to_url(xml_path_text)
    if not file_url:
        print(f"Could not normalize xml path: {xml_path_text}")
        return False

    filename = os.path.basename(file_url)
    out_path = os.path.join(author_dir, filename)

    print(f"Downloading TEI: {file_url}")
    try:
        r = session.get(file_url, timeout=30)
        r.raise_for_status()
        with open(out_path, "wb") as fh:
            fh.write(r.content)
        print(f"Saved: {out_path}")
        return True
    except Exception as e:
        print(f"Download failed: {e}")
        return False


def process_author(author_id: str, author_name: str, cf_id:str):
    author_name_sanitized = author_name.replace(" ", "_")
    author_dir = os.path.join(OUTPUT_BASE, cf_id)
    os.makedirs(author_dir, exist_ok=True)

    print(f"Downloading TEI XML for {author_name} (ID {author_id})")
    works = get_works_for_author(author_id)
    print(f"Found {len(works)} works for {author_name}.")

    total_downloaded = 0
    for w in works:
        wid = w["id"]
        wname = w.get("name", "")
        print(f"\n→ Work: {wname} (ID {wid})")
        texts = get_texts_for_work(author_id, wid)
        print(f"Found {len(texts)} text(s).")

        if not texts:
            if download_text_xml(author_dir, author_id, wid, ""):
                total_downloaded += 1
            continue

        for t in texts:
            tid = t["id"]
            tname = t.get("name", "")
            print(f"  - Text: {tname} (ID {tid})")
            if download_text_xml(author_dir, author_id, wid, tid):
                total_downloaded += 1
            time.sleep(0.15)
    print(f"Done for {author_name}: {total_downloaded} files saved in {author_dir}")


def main():
    # Load CSV
    df = pd.read_csv(CSV_PATH, sep=';', encoding='utf-8')
    df_with_cc = df[df['cc_id'].notna() & df['CF_ID'].notna()].copy()
    print(f"Found {len(df_with_cc)} authors with Corpus Corporum IDs.\n")

    # Iterate through authors
    for _, row in df_with_cc.iterrows():
        cc_id = str(int(row['cc_id']))  # e.g. 876.0 → '876'
        cf_id = row['CF_ID']
        name = row['Name']
        process_author(cc_id, name, cf_id)
        time.sleep(1)


if __name__ == "__main__":
    main()
# Out:
# Found 39 authors with Corpus Corporum IDs.
#
# Downloading TEI XML for Quintus Septimius Florens Tertullian (ID 867)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867&group_by=
# Found 48 works for Quintus Septimius Florens Tertullian.
#
# → Work: Ad Scapulam (ID 136)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/136&group_by=
# Found 2 text(s).
#   - Text: Responsa ex libris Digestorum (Auctor incertus), J. P. Migne (ID 37)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/136/37&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Auctor-incertus_Responsa-ex-libris-Digestorum.xml
# Saved: ../data/CF006/001_Auctor-incertus_Responsa-ex-libris-Digestorum.xml
#   - Text: Ad Scapulam (Tertullianus), J. P. Migne (ID 39)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/136/39&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_Ad-Scapulam.xml
# Saved: ../data/CF006/001_Tertullianus_Ad-Scapulam.xml
#
# → Work: Ad martyres (ID 137)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/137&group_by=
# Found 1 text(s).
#   - Text: Ad martyres (Tertullianus), J. P. Migne (ID 40)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/137/40&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_Ad-martyres.xml
# Saved: ../data/CF006/001_Tertullianus_Ad-martyres.xml
#
# → Work: Ad nationes (ID 138)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/138&group_by=
# Found 1 text(s).
#   - Text: Ad nationes (Tertullianus), J. P. Migne (ID 41)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/138/41&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_Ad-nationes.xml
# Saved: ../data/CF006/001_Tertullianus_Ad-nationes.xml
#
# → Work: Ad uxorem (ID 139)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/139&group_by=
# Found 1 text(s).
#   - Text: Ad uxorem (Tertullianus), J. P. Migne (ID 42)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/139/42&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_Ad-uxorem.xml
# Saved: ../data/CF006/001_Tertullianus_Ad-uxorem.xml
#
# → Work: Apologeticus adversus gentes (ID 140)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/140&group_by=
# Found 1 text(s).
#   - Text: Apologeticus adversus gentes (Tertullianus), J. P. Migne (ID 43)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/140/43&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_Apologeticus-adversus-gentes.xml
# Saved: ../data/CF006/001_Tertullianus_Apologeticus-adversus-gentes.xml
#
# → Work: De baptismo (ID 141)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/141&group_by=
# Found 1 text(s).
#   - Text: De baptismo (Tertullianus), J. P. Migne (ID 44)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/141/44&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-baptismo.xml
# Saved: ../data/CF006/001_Tertullianus_De-baptismo.xml
#
# → Work: De cultu feminarum (ID 142)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/142&group_by=
# Found 1 text(s).
#   - Text: De cultu feminarum (Tertullianus), J. P. Migne (ID 45)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/142/45&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-cultu-feminarum.xml
# Saved: ../data/CF006/001_Tertullianus_De-cultu-feminarum.xml
#
# → Work: De idololatria (ID 143)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/143&group_by=
# Found 1 text(s).
#   - Text: De idololatria (Tertullianus), J. P. Migne (ID 46)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/143/46&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-idololatria.xml
# Saved: ../data/CF006/001_Tertullianus_De-idololatria.xml
#
# → Work: De oratione (ID 144)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/144&group_by=
# Found 1 text(s).
#   - Text: De oratione (Tertullianus), J. P. Migne (ID 47)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/144/47&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-oratione.xml
# Saved: ../data/CF006/001_Tertullianus_De-oratione.xml
#
# → Work: De patientia (ID 145)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/145&group_by=
# Found 1 text(s).
#   - Text: De patientia (Tertullianus), J. P. Migne (ID 48)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/145/48&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-patientia.xml
# Saved: ../data/CF006/001_Tertullianus_De-patientia.xml
#
# → Work: De poenitentia (ID 146)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/146&group_by=
# Found 1 text(s).
#   - Text: De poenitentia (Tertullianus), J. P. Migne (ID 49)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/146/49&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-poenitentia.xml
# Saved: ../data/CF006/001_Tertullianus_De-poenitentia.xml
#
# → Work: De testimonio animae (ID 147)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/147&group_by=
# Found 1 text(s).
#   - Text: De testimonio animae (Tertullianus), J. P. Migne (ID 50)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/147/50&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/001_Tertullianus_De-testimonio-animae.xml
# Saved: ../data/CF006/001_Tertullianus_De-testimonio-animae.xml
#
# → Work: Adversus Hermogenem (ID 158)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/158&group_by=
# Found 1 text(s).
#   - Text: Adversus Hermogenem (Tertullianus), J. P. Migne (ID 61)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/158/61&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Adversus-Hermogenem.xml
# Saved: ../data/CF006/002_Tertullianus_Adversus-Hermogenem.xml
#
# → Work: Adversus Judaeos (ID 159)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/159&group_by=
# Found 1 text(s).
#   - Text: Adversus Judaeos (Tertullianus), J. P. Migne (ID 62)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/159/62&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Adversus-Judaeos.xml
# Saved: ../data/CF006/002_Tertullianus_Adversus-Judaeos.xml
#
# → Work: Adversus Marcionem (ID 160)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/160&group_by=
# Found 1 text(s).
#   - Text: Adversus Marcionem (Tertullianus), J. P. Migne (ID 63)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/160/63&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Adversus-Marcionem.xml
# Saved: ../data/CF006/002_Tertullianus_Adversus-Marcionem.xml
#
# → Work: Adversus Praxeam (ID 161)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/161&group_by=
# Found 1 text(s).
#   - Text: Adversus Praxeam (Tertullianus), J. P. Migne (ID 64)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/161/64&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Adversus-Praxeam.xml
# Saved: ../data/CF006/002_Tertullianus_Adversus-Praxeam.xml
#
# → Work: Adversus Valentinianos (ID 162)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/162&group_by=
# Found 1 text(s).
#   - Text: Adversus Valentinianos (Tertullianus), J. P. Migne (ID 65)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/162/65&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Adversus-Valentinianos.xml
# Saved: ../data/CF006/002_Tertullianus_Adversus-Valentinianos.xml
#
# → Work: De anima (ID 163)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/163&group_by=
# Found 1 text(s).
#   - Text: De anima (Tertullianus), J. P. Migne (ID 66)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/163/66&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-anima.xml
# Saved: ../data/CF006/002_Tertullianus_De-anima.xml
#
# → Work: De carne Christi (ID 164)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/164&group_by=
# Found 1 text(s).
#   - Text: De carne Christi (Tertullianus), J. P. Migne (ID 67)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/164/67&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-carne-Christi.xml
# Saved: ../data/CF006/002_Tertullianus_De-carne-Christi.xml
#
# → Work: De corona militis (ID 165)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/165&group_by=
# Found 1 text(s).
#   - Text: De corona militis (Tertullianus), J. P. Migne (ID 68)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/165/68&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-corona-militis.xml
# Saved: ../data/CF006/002_Tertullianus_De-corona-militis.xml
#
# → Work: De exhortatione castitatis (ID 166)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/166&group_by=
# Found 1 text(s).
#   - Text: De exhortatione castitatis (Tertullianus), J. P. Migne (ID 69)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/166/69&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-exhortatione-castitatis.xml
# Saved: ../data/CF006/002_Tertullianus_De-exhortatione-castitatis.xml
#
# → Work: De fuga in persecutione (ID 167)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/167&group_by=
# Found 1 text(s).
#   - Text: De fuga in persecutione (Tertullianus), J. P. Migne (ID 70)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/167/70&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-fuga-in-persecutione.xml
# Saved: ../data/CF006/002_Tertullianus_De-fuga-in-persecutione.xml
#
# → Work: De jejuniis (ID 168)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/168&group_by=
# Found 1 text(s).
#   - Text: De jejuniis (Tertullianus), J. P. Migne (ID 71)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/168/71&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-jejuniis.xml
# Saved: ../data/CF006/002_Tertullianus_De-jejuniis.xml
#
# → Work: De monogamia (ID 169)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/169&group_by=
# Found 1 text(s).
#   - Text: De monogamia (Tertullianus), J. P. Migne (ID 72)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/169/72&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-monogamia.xml
# Saved: ../data/CF006/002_Tertullianus_De-monogamia.xml
#
# → Work: De praescriptionibus adversus haereticos (ID 170)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/170&group_by=
# Found 1 text(s).
#   - Text: De praescriptionibus adversus haereticos (Tertullianus), J. P. Migne (ID 73)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/170/73&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-praescriptionibus-adversus-haereticos.xml
# Saved: ../data/CF006/002_Tertullianus_De-praescriptionibus-adversus-haereticos.xml
#
# → Work: De pudicitia (ID 171)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/171&group_by=
# Found 1 text(s).
#   - Text: De pudicitia (Tertullianus), J. P. Migne (ID 74)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/171/74&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-pudicitia.xml
# Saved: ../data/CF006/002_Tertullianus_De-pudicitia.xml
#
# → Work: De resurrectione carnis (ID 172)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/172&group_by=
# Found 1 text(s).
#   - Text: De resurrectione carnis (Tertullianus), J. P. Migne (ID 75)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/172/75&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-resurrectione-carnis.xml
# Saved: ../data/CF006/002_Tertullianus_De-resurrectione-carnis.xml
#
# → Work: De virginibus velandis (ID 173)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/173&group_by=
# Found 1 text(s).
#   - Text: De virginibus velandis (Tertullianus), J. P. Migne (ID 76)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/173/76&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_De-virginibus-velandis.xml
# Saved: ../data/CF006/002_Tertullianus_De-virginibus-velandis.xml
#
# → Work: Scorpiace adversus Gnosticos (ID 174)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/174&group_by=
# Found 1 text(s).
#   - Text: Scorpiace adversus Gnosticos (Tertullianus), J. P. Migne (ID 77)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/174/77&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/002_Tertullianus_Scorpiace-adversus-Gnosticos.xml
# Saved: ../data/CF006/002_Tertullianus_Scorpiace-adversus-Gnosticos.xml
#
# → Work: Apologeticum (ID 12371)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/12371&group_by=
# Found 1 text(s).
#   - Text: Apologeticum (Tertullianus), Tertullian-Minucius Felix (ID 12596)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/12371/12596&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus5_Latinitias_antiqua/Tertullianus_Apologeticum.xml
# Saved: ../data/CF006/Tertullianus_Apologeticum.xml
#
# → Work: De Spectaculis (ID 12400)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/12400&group_by=
# Found 1 text(s).
#   - Text: De Spectaculis (Tertullianus), Tertullian-Minucius Felix (ID 12628)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/12400/12628&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus5_Latinitias_antiqua/Tertullianus_De-Spectaculis.xml
# Saved: ../data/CF006/Tertullianus_De-Spectaculis.xml
#
# → Work: Ad nationes [CSEL] (ID 15059)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15059&group_by=
# Found 1 text(s).
#   - Text: Ad nationes [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14787)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15059/14787&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa002.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa002.opp-lat2.xml
#
# → Work: Adversus Hermogenem [CSEL] (ID 15061)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15061&group_by=
# Found 1 text(s).
#   - Text: Adversus Hermogenem [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14789)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15061/14789&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa004.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa004.opp-lat2.xml
#
# → Work: Adversus Marcionem [CSEL] (ID 15062)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15062&group_by=
# Found 1 text(s).
#   - Text: Adversus Marcionem [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14790)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15062/14790&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa006.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa006.opp-lat2.xml
#
# → Work: Adversus Praxeam [CSEL] (ID 15063)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15063&group_by=
# Found 1 text(s).
#   - Text: Adversus Praxeam [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14791)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15063/14791&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa007.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa007.opp-lat2.xml
#
# → Work: Adversus Valentinianos [CSEL] (ID 15064)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15064&group_by=
# Found 1 text(s).
#   - Text: Adversus Valentinianos [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14792)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15064/14792&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa008.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa008.opp-lat2.xml
#
# → Work: Adversus omnes haereses [CSEL] (ID 15067)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15067&group_by=
# Found 1 text(s).
#   - Text: Adversus omnes haereses [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14795)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15067/14795&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0276.stoa003.opp-lat2.xml
# Saved: ../data/CF006/stoa0276.stoa003.opp-lat2.xml
#
# → Work: De anima [CSEL] (ID 15135)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15135&group_by=
# Found 1 text(s).
#   - Text: De anima [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14864)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15135/14864&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa010.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa010.opp-lat2.xml
#
# → Work: De baptismo [CSEL] (ID 15137)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15137&group_by=
# Found 1 text(s).
#   - Text: De baptismo [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14866)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15137/14866&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa011.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa011.opp-lat2.xml
#
# → Work: De carnis resurrectione [CSEL] (ID 15142)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15142&group_by=
# Found 1 text(s).
#   - Text: De carnis resurrectione [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14871)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15142/14871&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa026.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa026.opp-lat2.xml
#
# → Work: De idololatria [CSEL] (ID 15163)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15163&group_by=
# Found 1 text(s).
#   - Text: De idololatria [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14892)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15163/14892&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa017.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa017.opp-lat2.xml
#
# → Work: De ieiunio [CSEL] (ID 15164)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15164&group_by=
# Found 1 text(s).
#   - Text: De ieiunio [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14893)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15164/14893&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa018.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa018.opp-lat2.xml
#
# → Work: De oratione [CSEL] (ID 15185)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15185&group_by=
# Found 1 text(s).
#   - Text: De oratione [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14914)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15185/14914&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa020.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa020.opp-lat2.xml
#
# → Work: De patientia [CSEL] (ID 15188)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15188&group_by=
# Found 1 text(s).
#   - Text: De patientia [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14917)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15188/14917&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa023.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa023.opp-lat2.xml
#
# → Work: De pudicitia [CSEL] (ID 15192)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15192&group_by=
# Found 1 text(s).
#   - Text: De pudicitia [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14921)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15192/14921&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa025.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa025.opp-lat2.xml
#
# → Work: De scorpiace [CSEL] (ID 15198)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15198&group_by=
# Found 1 text(s).
#   - Text: De scorpiace [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14927)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15198/14927&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa030.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa030.opp-lat2.xml
#
# → Work: De spectaculis [CSEL] (ID 15203)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15203&group_by=
# Found 1 text(s).
#   - Text: De spectaculis [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14932)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15203/14932&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa027.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa027.opp-lat2.xml
#
# → Work: De testimonio animae [CSEL] (ID 15206)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15206&group_by=
# Found 1 text(s).
#   - Text: De testimonio animae [CSEL] (Tertullianus), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14935)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=867/15206/14935&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0275.stoa028.opp-lat2.xml
# Saved: ../data/CF006/stoa0275.stoa028.opp-lat2.xml
# Done for Quintus Septimius Florens Tertullian: 49 files saved in ../data/CF006
# Downloading TEI XML for Sidonius Apollinaris (ID 1114)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1114&group_by=
# Found 3 works for Sidonius Apollinaris.
#
# → Work: Carmina (ID 2686)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1114/2686&group_by=
# Found 3 text(s).
#   - Text: Carmina (Sidonius Apollinaris), J. P. Migne (ID 7676)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1114/2686/7676&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/058_Sidonius-Apollinaris_Carmina.xml
# Saved: ../data/CF008/058_Sidonius-Apollinaris_Carmina.xml
#   - Text: Carmina (Sidonius Apollinaris), Sidonius Poems and Letters, Vol 1 (ID 12610)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1114/2686/12610&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus5_Latinitias_antiqua/Sidonius-Apollinaris_Carmina.xml
# Saved: ../data/CF008/Sidonius-Apollinaris_Carmina.xml
#   - Text: Carmina (Sidonius Apollinaris), publ. Weidmann (ID 16689)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1114/2686/16689&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus22_MGH/797_Sidonius-Apollinaris_Carmina.xml
# Saved: ../data/CF008/797_Sidonius-Apollinaris_Carmina.xml
#
# → Work: Epistolae (ID 2687)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1114/2687&group_by=
# Found 2 text(s).
#   - Text: Epistolae (Sidonius Apollinaris), J. P. Migne (ID 7677)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1114/2687/7677&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/058_Sidonius-Apollinaris_Epistolae.xml
# Saved: ../data/CF008/058_Sidonius-Apollinaris_Epistolae.xml
#   - Text: Epistolae (Sidonius Apollinaris), publ. Weidmann (ID 16794)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1114/2687/16794&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus22_MGH/797_Sidonius-Apollinaris_Epistolae.xml
# Saved: ../data/CF008/797_Sidonius-Apollinaris_Epistolae.xml
#
# → Work: Epistulae (ID 12452)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1114/12452&group_by=
# Found 1 text(s).
#   - Text: Epistulae (Sidonius Apollinaris), Sidonius Poems and Letters, Vol 1-2 (ID 12680)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1114/12452/12680&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus5_Latinitias_antiqua/Sidonius-Apollinaris_Epistulae.xml
# Saved: ../data/CF008/Sidonius-Apollinaris_Epistulae.xml
# Done for Sidonius Apollinaris: 6 files saved in ../data/CF008
# Downloading TEI XML for Origenes (ID 1049)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049&group_by=
# Found 6 works for Origenes.
#
# → Work: Interpretatio homiliarum Origenis in Canticum canticorum (ID 608)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/608&group_by=
# Found 1 text(s).
#   - Text: Interpretatio homiliarum Origenis in Canticum canticorum (Origenes; Hieronymus Stridonensis), J. P. Migne (ID 7164)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/608/7164&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/023_Origenes_-Hieronymus-Stridonensis_Interpretatio-homiliarum-Origenis-in-Canticum-canticorum.xml
# Saved: ../data/CF009/023_Origenes_-Hieronymus-Stridonensis_Interpretatio-homiliarum-Origenis-in-Canticum-canticorum.xml
#
# → Work: Translatio homiliarum in visiones Isaiae (ID 616)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/616&group_by=
# Found 1 text(s).
#   - Text: Translatio homiliarum in visiones Isaiae (Origenes; Hieronymus Stridonensis), J. P. Migne (ID 7172)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/616/7172&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/024_Origenes_-Hieronymus-Stridonensis_Translatio-homiliarum-in-visiones-Isaiae.xml
# Saved: ../data/CF009/024_Origenes_-Hieronymus-Stridonensis_Translatio-homiliarum-in-visiones-Isaiae.xml
#
# → Work: Translatio Homiliarum in Jeremiam et Ezechielem (ID 626)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/626&group_by=
# Found 1 text(s).
#   - Text: Translatio Homiliarum in Jeremiam et Ezechielem (Origenes; Hieronymus Stridonensis), J. P. Migne (ID 7182)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/626/7182&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/025_Origenes_-Hieronymus-Stridonensis_Translatio-Homiliarum-in-Jeremiam-et-Ezechielem.xml
# Saved: ../data/CF009/025_Origenes_-Hieronymus-Stridonensis_Translatio-Homiliarum-in-Jeremiam-et-Ezechielem.xml
#
# → Work: Translatio XXXIX Homiliarum (ID 636)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/636&group_by=
# Found 1 text(s).
#   - Text: Translatio XXXIX Homiliarum (Origenes; Hieronymus Stridonensis), J. P. Migne (ID 7192)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/636/7192&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/026_Origenes_-Hieronymus-Stridonensis_Translatio-XXXIX-Homiliarum.xml
# Saved: ../data/CF009/026_Origenes_-Hieronymus-Stridonensis_Translatio-XXXIX-Homiliarum.xml
#
# → Work: De incarnatione Verbi (ID 2463)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/2463&group_by=
# Found 1 text(s).
#   - Text: De incarnatione Verbi (Origenes), J. P. Migne (ID 7448)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/2463/7448&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/042_Origenes_De-incarnatione-Verbi.xml
# Saved: ../data/CF009/042_Origenes_De-incarnatione-Verbi.xml
#
# → Work: De principiis (ID 21749)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/21749&group_by=
# Found 1 text(s).
#   - Text: De Principiis (Origenes, trans. Rufinus), Méquignon-Havard (ID 21750)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1049/21749/21750&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus10_Philosophica/Origenes_De-principiis.xml
# Saved: ../data/CF009/Origenes_De-principiis.xml
# Done for Origenes: 6 files saved in ../data/CF009
# Downloading TEI XML for Cyprian (ID 878)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878&group_by=
# Found 34 works for Cyprian.
#
# → Work: Epistola (ID 191)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/191&group_by=
# Found 1 text(s).
#   - Text: Epistola (Cyprianus Carthaginensis), J. P. Migne (ID 94)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/191/94&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/003_Cyprianus-Carthaginensis_Epistola.xml
# Saved: ../data/CF010/003_Cyprianus-Carthaginensis_Epistola.xml
#
# → Work: Epistolae 1 (ID 192)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/192&group_by=
# Found 1 text(s).
#   - Text: Epistolae 1 (Cyprianus Carthaginensis), J. P. Migne (ID 95)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/192/95&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/003_Cyprianus-Carthaginensis_Epistolae-1.xml
# Saved: ../data/CF010/003_Cyprianus-Carthaginensis_Epistolae-1.xml
#
# → Work: Epistolae de baptismate haereticorum (ID 193)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/193&group_by=
# Found 1 text(s).
#   - Text: Epistolae de baptismate haereticorum (Cyprianus Carthaginensis), J. P. Migne (ID 96)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/193/96&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/003_Cyprianus-Carthaginensis_Epistolae-de-baptismate-haereticorum.xml
# Saved: ../data/CF010/003_Cyprianus-Carthaginensis_Epistolae-de-baptismate-haereticorum.xml
#
# → Work: Ad Demetrianum (ID 214)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/214&group_by=
# Found 1 text(s).
#   - Text: Ad Demetrianum (Cyprianus Carthaginensis), J. P. Migne (ID 117)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/214/117&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_Ad-Demetrianum.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_Ad-Demetrianum.xml
#
# → Work: De bono patientiae (ID 215)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/215&group_by=
# Found 1 text(s).
#   - Text: De bono patientiae (Cyprianus Carthaginensis), J. P. Migne (ID 118)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/215/118&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-bono-patientiae.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-bono-patientiae.xml
#
# → Work: De habitu virginum (ID 216)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/216&group_by=
# Found 1 text(s).
#   - Text: De habitu virginum (Cyprianus Carthaginensis), J. P. Migne (ID 119)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/216/119&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-habitu-virginum.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-habitu-virginum.xml
#
# → Work: De idolorum vanitate (ID 217)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/217&group_by=
# Found 1 text(s).
#   - Text: De idolorum vanitate (Cyprianus Carthaginensis), J. P. Migne (ID 120)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/217/120&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-idolorum-vanitate.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-idolorum-vanitate.xml
#
# → Work: De lapsis (ID 218)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/218&group_by=
# Found 1 text(s).
#   - Text: De lapsis (Cyprianus Carthaginensis), J. P. Migne (ID 121)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/218/121&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-lapsis.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-lapsis.xml
#
# → Work: De laude martyrii (ID 219)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/219&group_by=
# Found 1 text(s).
#   - Text: De laude martyrii (Cyprianus Carthaginensis), J. P. Migne (ID 122)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/219/122&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-laude-martyrii.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-laude-martyrii.xml
#
# → Work: De mortalitate (ID 220)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/220&group_by=
# Found 1 text(s).
#   - Text: De mortalitate (Cyprianus Carthaginensis), J. P. Migne (ID 123)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/220/123&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-mortalitate.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-mortalitate.xml
#
# → Work: De opere et eleemosynis (ID 221)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/221&group_by=
# Found 1 text(s).
#   - Text: De opere et eleemosynis (Cyprianus Carthaginensis), J. P. Migne (ID 124)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/221/124&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-opere-et-eleemosynis.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-opere-et-eleemosynis.xml
#
# → Work: De oratione dominica (ID 222)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/222&group_by=
# Found 1 text(s).
#   - Text: De oratione dominica (Cyprianus Carthaginensis), J. P. Migne (ID 125)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/222/125&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-oratione-dominica.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-oratione-dominica.xml
#
# → Work: De spectaculis (ID 223)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/223&group_by=
# Found 1 text(s).
#   - Text: De spectaculis (Cyprianus Carthaginensis), J. P. Migne (ID 126)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/223/126&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-spectaculis.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-spectaculis.xml
#
# → Work: De unitate ecclesiae (ID 224)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/224&group_by=
# Found 1 text(s).
#   - Text: De unitate ecclesiae (Cyprianus Carthaginensis), J. P. Migne (ID 127)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/224/127&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-unitate-ecclesiae.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-unitate-ecclesiae.xml
#
# → Work: De zelo et livore (ID 225)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/225&group_by=
# Found 1 text(s).
#   - Text: De zelo et livore (Cyprianus Carthaginensis), J. P. Migne (ID 128)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/225/128&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_De-zelo-et-livore.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_De-zelo-et-livore.xml
#
# → Work: Epistola de exhortatione martyrii (ID 226)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/226&group_by=
# Found 1 text(s).
#   - Text: Epistola de exhortatione martyrii (Cyprianus Carthaginensis), J. P. Migne (ID 129)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/226/129&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_Epistola-de-exhortatione-martyrii.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_Epistola-de-exhortatione-martyrii.xml
#
# → Work: Epistolae 2 (ID 227)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/227&group_by=
# Found 1 text(s).
#   - Text: Epistolae 2 (Cyprianus Carthaginensis), J. P. Migne (ID 130)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/227/130&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_Epistolae-2.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_Epistolae-2.xml
#
# → Work: Ad Demetrianum [CSEL] (ID 15053)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15053&group_by=
# Found 1 text(s).
#   - Text: Ad Demetrianum [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14781)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15053/14781&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa002.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa002.opp-lat1.xml
#
# → Work: Ad Donatum [CSEL] (ID 15054)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15054&group_by=
# Found 1 text(s).
#   - Text: Ad Donatum [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14782)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15054/14782&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa001.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa001.opp-lat1.xml
#
# → Work: Ad Fortunatum [CSEL] (ID 15055)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15055&group_by=
# Found 1 text(s).
#   - Text: Ad Fortunatum [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14783)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15055/14783&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa005.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa005.opp-lat1.xml
#
# → Work: De Bono Patientiae [CSEL] (ID 15113)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15113&group_by=
# Found 1 text(s).
#   - Text: De Bono Patientiae [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14842)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15113/14842&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa003.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa003.opp-lat1.xml
#
# → Work: De Habitu Virginum [CSEL] (ID 15117)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15117&group_by=
# Found 1 text(s).
#   - Text: De Habitu Virginum [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14846)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15117/14846&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa004.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa004.opp-lat1.xml
#
# → Work: De Lapsis [CSEL] (ID 15122)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15122&group_by=
# Found 1 text(s).
#   - Text: De Lapsis [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14851)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15122/14851&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa007.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa007.opp-lat1.xml
#
# → Work: De Mortalitate [CSEL] (ID 15123)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15123&group_by=
# Found 1 text(s).
#   - Text: De Mortalitate [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14852)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15123/14852&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa008.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa008.opp-lat1.xml
#
# → Work: De catholicae Ecclesiae unitate [CSEL] (ID 15143)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15143&group_by=
# Found 1 text(s).
#   - Text: De catholicae Ecclesiae unitate [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14872)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15143/14872&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa010.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa010.opp-lat1.xml
#
# → Work: De dominica oratione[CSEL] (ID 15150)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15150&group_by=
# Found 1 text(s).
#   - Text: De dominica oratione[CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14879)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15150/14879&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa015.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa015.opp-lat1.xml
#
# → Work: De opere et eleemosynis [CSEL] (ID 15182)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15182&group_by=
# Found 1 text(s).
#   - Text: De opere et eleemosynis [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14911)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15182/14911&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa009.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa009.opp-lat1.xml
#
# → Work: De zelo et livore [CSEL] (ID 15209)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15209&group_by=
# Found 1 text(s).
#   - Text: De zelo et livore [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14939)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15209/14939&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa011.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa011.opp-lat1.xml
#
# → Work: Epistulae [CSEL] (ID 15229)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15229&group_by=
# Found 1 text(s).
#   - Text: Epistulae [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14958)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15229/14958&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa012.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa012.opp-lat1.xml
#
# → Work: Heptateuchos [CSEL] (ID 15255)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15255&group_by=
# Found 1 text(s).
#   - Text: Heptateuchos [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 14986)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15255/14986&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104c.stoa001.opp-lat1.xml
# Saved: ../data/CF010/stoa0104c.stoa001.opp-lat1.xml
#
# → Work: Quod idola Dii non sint [CSEL] (ID 15300)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15300&group_by=
# Found 1 text(s).
#   - Text: Quod idola Dii non sint [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 15031)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15300/15031&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa006.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa006.opp-lat1.xml
#
# → Work: Sententiae episcoporum [CSEL] (ID 15303)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15303&group_by=
# Found 1 text(s).
#   - Text: Sententiae episcoporum [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 15034)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15303/15034&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa013.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa013.opp-lat1.xml
#
# → Work: Testimonia ad Quirinum [CSEL] (ID 15309)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15309&group_by=
# Found 1 text(s).
#   - Text: Testimonia ad Quirinum [CSEL] (Cyprianus Carthaginensis), publ. Österreichische Akademie der Wissenschaften (ÖAW) (ID 15040)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/15309/15040&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus19_Scriptores_Ecclesiastici/stoa0104a.stoa014.opp-lat1.xml
# Saved: ../data/CF010/stoa0104a.stoa014.opp-lat1.xml
#
# → Work: Testimonia adversus Judaeos (ID 21557)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/21557&group_by=
# Found 1 text(s).
#   - Text: Testimonia adversus Judaeos (Cyprianus Carthaginensis), J. P. Migne (ID 21445)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=878/21557/21445&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/004_Cyprianus-Carthaginensis_Testimonia-adversus-Judaeos.xml
# Saved: ../data/CF010/004_Cyprianus-Carthaginensis_Testimonia-adversus-Judaeos.xml
# Done for Cyprian: 34 files saved in ../data/CF010
# Downloading TEI XML for Eusebius von Caesarea (ID 919)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=919&group_by=
# Found 2 works for Eusebius von Caesarea.
#
# → Work: Vita Constantini (ID 288)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=919/288&group_by=
# Found 1 text(s).
#   - Text: Vita Constantini (Eusebius Pamphilus), J. P. Migne (ID 6843)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=919/288/6843&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/008_Eusebius-Pamphilus_Vita-Constantini.xml
# Saved: ../data/CF011/008_Eusebius-Pamphilus_Vita-Constantini.xml
#
# → Work: Canones Evangeliorum (ID 664)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=919/664&group_by=
# Found 1 text(s).
#   - Text: Canones Evangeliorum (Eusebius Pamphilus), J. P. Migne (ID 7221)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=919/664/7221&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/029_Eusebius-Pamphilus_Canones-Evangeliorum.xml
# Saved: ../data/CF011/029_Eusebius-Pamphilus_Canones-Evangeliorum.xml
# Done for Eusebius von Caesarea: 2 files saved in ../data/CF011
# Downloading TEI XML for Hilarius von Poitiers (ID 927)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927&group_by=
# Found 28 works for Hilarius von Poitiers.
#
# → Work: Commentarius in Matthaeum (ID 308)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/308&group_by=
# Found 1 text(s).
#   - Text: Commentarius in Matthaeum (Hilarius Pictaviensis), J. P. Migne (ID 6863)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/308/6863&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/009_Hilarius-Pictaviensis_Commentarius-in-Matthaeum.xml
# Saved: ../data/CF012/009_Hilarius-Pictaviensis_Commentarius-in-Matthaeum.xml
#
# → Work: Commentarius in psalmos XV XXXI XLI (ID 309)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/309&group_by=
# Found 1 text(s).
#   - Text: Commentarius in psalmos XV XXXI XLI (Hilarius Pictaviensis), J. P. Migne (ID 6864)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/309/6864&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/009_Hilarius-Pictaviensis_Commentarius-in-psalmos-XV-XXXI-XLI.xml
# Saved: ../data/CF012/009_Hilarius-Pictaviensis_Commentarius-in-psalmos-XV-XXXI-XLI.xml
#
# → Work: Apologetica responsa ad reprehensores libri de synodis (ID 315)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=927/315&group_by=
# Found 1 text(s).
# ...
# Found 1 text(s).
#   - Text: Epistola LXXXVIII (Leo I), J. P. Migne (ID 7640)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1098/2652/7640&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/055_Leo-I_Epistola-LXXXVIII.xml
# Saved: ../data/CF051/055_Leo-I_Epistola-LXXXVIII.xml
#
# → Work: Sacramenta Romanae Ecclesiae (ID 2653)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1098/2653&group_by=
# Found 1 text(s).
#   - Text: Sacramenta Romanae Ecclesiae (Leo I), J. P. Migne (ID 7641)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1098/2653/7641&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/055_Leo-I_Sacramenta-Romanae-Ecclesiae.xml
# Saved: ../data/CF051/055_Leo-I_Sacramenta-Romanae-Ecclesiae.xml
#
# → Work: Epistola ad Flavianum (ID 2737)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1098/2737&group_by=
# Found 1 text(s).
#   - Text: Epistola ad Flavianum (Leo I), J. P. Migne (ID 7729)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1098/2737/7729&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/062_Leo-I_Epistola-ad-Flavianum.xml
# Saved: ../data/CF051/062_Leo-I_Epistola-ad-Flavianum.xml
#
# → Work: Sermones inediti (ID 21553)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1098/21553&group_by=
# Found 1 text(s).
#   - Text: Sermones inediti (Leo I), J. P. Migne (ID 21442)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1098/21553/21442&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/056_Leo-I_Sermones-inediti.xml
# Saved: ../data/CF051/056_Leo-I_Sermones-inediti.xml
# Done for Leo I. (der Große): 13 files saved in ../data/CF051
# Downloading TEI XML for Prosper von Aquitanien (ID 1016)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016&group_by=
# Found 24 works for Prosper von Aquitanien.
#
# → Work: Chronicon Prosperi Aquitanici (ID 638)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/638&group_by=
# Found 1 text(s).
#   - Text: Chronicon Prosperi Aquitanici (Prosper Aquitanus), J. P. Migne (ID 7194)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/638/7194&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/027_Prosper-Aquitanus_Chronicon-Prosperi-Aquitanici.xml
# Saved: ../data/CF052/027_Prosper-Aquitanus_Chronicon-Prosperi-Aquitanici.xml
#
# → Work: Epistola CCXXV (ID 2503)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2503&group_by=
# Found 1 text(s).
#   - Text: Epistola CCXXV (Prosper Aquitanus), J. P. Migne (ID 7488)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2503/7488&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/044_Prosper-Aquitanus_Epistola-CCXXV.xml
# Saved: ../data/CF052/044_Prosper-Aquitanus_Epistola-CCXXV.xml
#
# → Work: Contra Collatorem (ID 2512)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2512&group_by=
# Found 2 text(s).
#   - Text: Contra Collatorem (Prosper Aquitanus), J. P. Migne (ID 7497)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2512/7497&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/045_Prosper-Aquitanus_Contra-Collatorem.xml
# Saved: ../data/CF052/045_Prosper-Aquitanus_Contra-Collatorem.xml
#   - Text: Contra collatorem (Prosper Aquitanus), J. P. Migne (ID 7574)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2512/7574&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Contra-collatorem.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Contra-collatorem.xml
#
# → Work: De gratia et libero arbitrio (ID 2513)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2513&group_by=
# Found 1 text(s).
#   - Text: De gratia et libero arbitrio (Prosper Aquitanus), J. P. Migne (ID 7498)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2513/7498&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/045_Prosper-Aquitanus_De-gratia-et-libero-arbitrio.xml
# Saved: ../data/CF052/045_Prosper-Aquitanus_De-gratia-et-libero-arbitrio.xml
#
# → Work: Epigramma in obtrectatorem Augustini (ID 2514)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2514&group_by=
# Found 1 text(s).
#   - Text: Epigramma in obtrectatorem Augustini (Prosper Aquitanus), J. P. Migne (ID 7499)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2514/7499&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/045_Prosper-Aquitanus_Epigramma-in-obtrectatorem-Augustini.xml
# Saved: ../data/CF052/045_Prosper-Aquitanus_Epigramma-in-obtrectatorem-Augustini.xml
#
# → Work: Responsiones ad capitula Gallorum (ID 2515)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2515&group_by=
# Found 1 text(s).
#   - Text: Responsiones ad capitula Gallorum (Prosper Aquitanus), J. P. Migne (ID 7500)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2515/7500&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/045_Prosper-Aquitanus_Responsiones-ad-capitula-Gallorum.xml
# Saved: ../data/CF052/045_Prosper-Aquitanus_Responsiones-ad-capitula-Gallorum.xml
#
# → Work: Responsiones ad excerpta Genuensium (ID 2516)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2516&group_by=
# Found 1 text(s).
#   - Text: Responsiones ad excerpta Genuensium (Prosper Aquitanus), J. P. Migne (ID 7501)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2516/7501&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/045_Prosper-Aquitanus_Responsiones-ad-excerpta-Genuensium.xml
# Saved: ../data/CF052/045_Prosper-Aquitanus_Responsiones-ad-excerpta-Genuensium.xml
#
# → Work: Responsiones ad objectiones Vincentianas (ID 2517)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2517&group_by=
# Found 1 text(s).
#   - Text: Responsiones ad objectiones Vincentianas (Prosper Aquitanus), J. P. Migne (ID 7502)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2517/7502&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/045_Prosper-Aquitanus_Responsiones-ad-objectiones-Vincentianas.xml
# Saved: ../data/CF052/045_Prosper-Aquitanus_Responsiones-ad-objectiones-Vincentianas.xml
#
# → Work: Sententiae delibatae ex Augustino (ID 2518)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2518&group_by=
# Found 1 text(s).
#   - Text: Sententiae delibatae ex Augustino (Prosper Aquitanus), J. P. Migne (ID 7503)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2518/7503&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/045_Prosper-Aquitanus_Sententiae-delibatae-ex-Augustino.xml
# Saved: ../data/CF052/045_Prosper-Aquitanus_Sententiae-delibatae-ex-Augustino.xml
#
# → Work: Appendicula ad Chronicum (ID 2585)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2585&group_by=
# Found 1 text(s).
#   - Text: Appendicula ad Chronicum (Prosper Aquitanus), J. P. Migne (ID 7571)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2585/7571&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Appendicula-ad-Chronicum.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Appendicula-ad-Chronicum.xml
#
# → Work: Carmen de ingratis (ID 2586)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2586&group_by=
# Found 1 text(s).
#   - Text: Carmen de ingratis (Prosper Aquitanus), J. P. Migne (ID 7572)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2586/7572&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Carmen-de-ingratis.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Carmen-de-ingratis.xml
#
# → Work: Chronicum integrum (ID 2587)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2587&group_by=
# Found 1 text(s).
#   - Text: Chronicum integrum (Prosper Aquitanus), J. P. Migne (ID 7573)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2587/7573&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Chronicum-integrum.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Chronicum-integrum.xml
#
# → Work: De gratia Dei et libero arbitrio voluntatis (ID 2588)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2588&group_by=
# Found 1 text(s).
#   - Text: De gratia Dei et libero arbitrio voluntatis (Prosper Aquitanus), J. P. Migne (ID 7575)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2588/7575&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_De-gratia-Dei-et-libero-arbitrio-voluntatis.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_De-gratia-Dei-et-libero-arbitrio-voluntatis.xml
#
# → Work: Epigramma alterum in obtractorem Augustini (ID 2589)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2589&group_by=
# Found 1 text(s).
#   - Text: Epigramma alterum in obtractorem Augustini (Prosper Aquitanus), J. P. Migne (ID 7576)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2589/7576&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Epigramma-alterum-in-obtractorem-Augustini.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Epigramma-alterum-in-obtractorem-Augustini.xml
#
# → Work: Epigramma in obtractorem Augustini (ID 2590)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2590&group_by=
# Found 1 text(s).
#   - Text: Epigramma in obtractorem Augustini (Prosper Aquitanus), J. P. Migne (ID 7577)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2590/7577&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Epigramma-in-obtractorem-Augustini.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Epigramma-in-obtractorem-Augustini.xml
#
# → Work: Epigrammata ex sententiis Augustini (ID 2591)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2591&group_by=
# Found 1 text(s).
#   - Text: Epigrammata ex sententiis Augustini (Prosper Aquitanus), J. P. Migne (ID 7578)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2591/7578&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Epigrammata-ex-sententiis-Augustini.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Epigrammata-ex-sententiis-Augustini.xml
#
# → Work: Epistola ad Rufinum (ID 2592)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2592&group_by=
# Found 1 text(s).
#   - Text: Epistola ad Rufinum (Prosper Aquitanus), J. P. Migne (ID 7579)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2592/7579&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Epistola-ad-Rufinum.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Epistola-ad-Rufinum.xml
#
# → Work: Epistola ad Augustinum (ID 2593)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2593&group_by=
# Found 1 text(s).
#   - Text: Epistola ad Augustinum (Prosper Aquitanus), J. P. Migne (ID 7580)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2593/7580&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Epistola_ad_Augustinum.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Epistola_ad_Augustinum.xml
#
# → Work: Epitaphium Nestorianae et Pelagianae haeresium (ID 2594)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2594&group_by=
# Found 1 text(s).
#   - Text: Epitaphium Nestorianae et Pelagianae haeresium (Prosper Aquitanus), J. P. Migne (ID 7581)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2594/7581&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Epitaphium-Nestorianae-et-Pelagianae-haeresium.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Epitaphium-Nestorianae-et-Pelagianae-haeresium.xml
#
# → Work: Expositio Psalmorum a C usque ad CL (ID 2595)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2595&group_by=
# Found 1 text(s).
#   - Text: Expositio Psalmorum a C usque ad CL (Prosper Aquitanus), J. P. Migne (ID 7582)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2595/7582&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Expositio-Psalmorum-a-C-usque-ad-CL.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Expositio-Psalmorum-a-C-usque-ad-CL.xml
#
# → Work: Responsiones pro Augustino ad capitula Gallorum (ID 2596)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2596&group_by=
# Found 1 text(s).
#   - Text: Responsiones pro Augustino ad capitula Gallorum (Prosper Aquitanus), J. P. Migne (ID 7583)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2596/7583&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Responsiones-pro-Augustino-ad-capitula-Gallorum.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Responsiones-pro-Augustino-ad-capitula-Gallorum.xml
#
# → Work: Responsiones pro Augustino ad excerpta Genuensium (ID 2597)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2597&group_by=
# Found 1 text(s).
#   - Text: Responsiones pro Augustino ad excerpta Genuensium (Prosper Aquitanus), J. P. Migne (ID 7584)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2597/7584&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Responsiones-pro-Augustino-ad-excerpta-Genuensium.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Responsiones-pro-Augustino-ad-excerpta-Genuensium.xml
#
# → Work: Sententiae delibatae ex operibus S. Augustini (ID 2598)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2598&group_by=
# Found 1 text(s).
#   - Text: Sententiae delibatae ex operibus S. Augustini (Prosper Aquitanus), J. P. Migne (ID 7585)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/2598/7585&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Sententiae-delibatae-ex-operibus-S.-Augustini.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Sententiae-delibatae-ex-operibus-S.-Augustini.xml
#
# → Work: Responsiones pro Augustino ad capitula objectionum Vincentianarum (ID 21549)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/21549&group_by=
# Found 1 text(s).
#   - Text: Responsiones pro Augustino ad capitula objectionum Vincentianarum (Prosper Aquitanus), J. P. Migne (ID 21437)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=1016/21549/21437&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/051_Prosper-Aquitanus_Responsiones-pro-Augustino-ad-capitula-objectionum-Vincentianarum.xml
# Saved: ../data/CF052/051_Prosper-Aquitanus_Responsiones-pro-Augustino-ad-capitula-objectionum-Vincentianarum.xml
# Done for Prosper von Aquitanien: 25 files saved in ../data/CF052
# Downloading TEI XML for Ephrem der Syrer (ID 20426)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=20426&group_by=
# Found 2 works for Ephrem der Syrer.
#
# → Work: Vita S. Abrahae (ID 3013)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=20426/3013&group_by=
# Found 1 text(s).
#   - Text: Vita S. Abrahae (Ephraem Edessensis; Auctor incertus), J. P. Migne (ID 8014)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=20426/3013/8014&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/073_Ephraem-Edessensis_-Auctor-incertus_Vita-S.-Abrahae.xml
# Saved: ../data/CF053/073_Ephraem-Edessensis_-Auctor-incertus_Vita-S.-Abrahae.xml
#
# → Work: Vita S. Mariae meretricis (ID 3014)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=20426/3014&group_by=
# Found 1 text(s).
#   - Text: Vita S. Mariae meretricis (Ephraem Edessensis; Auctor incertus), J. P. Migne (ID 8015)
# Fetching: https://mlat.uzh.ch/php_modules/navigate.php?load=20426/3014/8015&group_by=
# Downloading TEI: https://mlat.uzh.ch/data/Corpus2_PL/073_Ephraem-Edessensis_-Auctor-incertus_Vita-S.-Mariae-meretricis.xml
# Saved: ../data/CF053/073_Ephraem-Edessensis_-Auctor-incertus_Vita-S.-Mariae-meretricis.xml
# Done for Ephrem der Syrer: 2 files saved in ../data/CF053
